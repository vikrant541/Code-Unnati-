# %%
# DATA VISUALISATION

# %%
pip instal matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "instal" - maybe you meant "install"

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\vikra\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vikra\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\vikra\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vikra\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\vikra\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\vikra\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vikra\anaconda3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\vikra\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vikra\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\vikra\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt
#x axis values
x = [1,2,3]
# coressponding y axis values
y = [2,4,1]
# plotting the values 
plt.plot(x,y)
#naming the x axis
plt.xlabel('x-axis')
#naming the y axis
plt.ylabel('y-axis')
#giving the title
plt.title('my first graph')
plt.show()

# %%
import numpy as np
x = np.arange(0,10,0.1)
y= np.sin(x)

#figure in matplotlib using figure()
plt.figure(figsize=(10,8))
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
x = np.arange(0,10,0.1)
y= np.cos(x)

#figure in matplotlib using figure()
plt.figure(figsize=(10,8))
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
x = np.arange(0,10,0.1)
y= np.tan(x)

#figure in matplotlib using figure()
plt.figure(figsize=(10,8))
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plot1
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x,y)

#plot2
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])

plt.subplot(2,1,2)
plt.plot(x,y)

# %%
#plot1
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(1,6,1)
plt.plot(x,y)

#plot2
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])

plt.subplot(1,6,2)
plt.plot(x,y)

#plot3
x = np.array([4,5,7,8])
y = np.array([9,10,11,23])
plt.subplot(1,6,3)
plt.plot(x,y)

#plot4
x = np.array([0,1,2,3])
y = np.array([3,8,9,5])

plt.subplot(1,6,4)
plt.plot(x,y)

# %%
#plot1
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)

#plot2
x = np.array([56,34,34,56])
y = np.array([10,20,30,40])

plt.subplot(1,2,2)
plt.plot(x,y)

#plot3
x = np.array([7,5,7,8])
y = np.array([9,10,11,23])
plt.subplot(2,1,1)
plt.plot(x,y)

#plot4
x = np.array([3,4,5,6])
y = np.array([3,8,9,5])

plt.subplot(2,1,2)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3,8,1,10])
plt.plot(ypoints, marker = 'o')
plt.show()

# %%
ypoints = np.array([30,40,50,60])
plt.plot(ypoints, marker = '^', ms = '20', mec = 'r', markerfacecolor = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3,8,1,10])
plt.plot(ypoints, linestyle = 'dotted', color = 'r')
plt.show()

# %%
from matplotlib import pyplot as plt
x = [5,2,4,9,7]

y =[10,5,8,4,2]
plt.plot(x,y)
plt.show()

# %%
from matplotlib import pyplot as plt
x = [5,2,4,9,7]

y =[10,5,8,4,2]
plt.bar(x,y)
plt.show()

# %%
from matplotlib import pyplot as plt
x = [5,2,4,9,7,6,8,9,2]

y =[10,5,8,4,2,8,9,4,5]
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np

x = [5,10,15,20,25,30,35,40,45,50]
y = [1,4,3,2,7,6,9,8,10,5]

plt.plot(x,y, 'g')
plt.xlabel('x')
plt.ylabel('y')

plt.tick_params(axis="x", labelsize=18, labelrotation=-60, labelcolor="blue")

plt.tick_params(axis="y", labelsize=12, labelrotation=20, labelcolor="black")

# %%
import matplotlib.pyplot as plt 
import numpy as np

y1 = [2,3,4.5]
y2 = [1,1.5,5]

plt.plot(y1)
plt.plot(y2)

plt.legend(["blue", "green"], loc = "best")
plt.show()

# %%
data = np.random.normal(170,10,250)
plt.hist(data);
plt.show()
plt.hist(data, bins = 30);
plt.show()

# %%
data = np.random.normal(170,10,250)
plt.hist(data);
print(data)
plt.show()
plt.hist(data, bins = 50);
plt.show()
# Out:
# [144.616988   179.57731748 166.80172469 158.58554289 157.20747581
#  185.51244571 181.86250772 157.07351276 168.72271665 187.80352593
#  183.16636181 168.48871846 161.91554929 168.65697932 169.38346138
#  165.71237984 153.79634132 168.34344729 156.72767273 174.56610332
#  167.58935812 161.26066488 167.69127109 169.59472921 154.79947443
#  176.44222266 158.58229134 172.91603195 184.08013619 167.8494246
#  163.14279432 161.67713814 161.39318563 144.68529176 167.88173694
#  189.01182485 163.93123284 172.74906033 188.65378527 174.18860054
#  168.78389318 179.3259797  175.11490938 172.71575676 167.91217791
#  164.39489228 171.82892221 158.21858542 167.27180729 147.51185818
#  172.78955465 172.43759822 159.08833931 162.40101861 159.54384725
#  188.25791769 179.00961001 164.3404117  153.42461808 180.25068291
#  169.77207312 167.41234229 163.08520695 167.81152846 167.81841274
#  162.94476689 174.21171892 171.60707172 186.58862601 173.1343703
#  174.68378574 160.30777129 193.58797537 176.43056246 175.9337005
#  148.25619385 179.56018509 172.60851232 166.91000449 171.00030002
#  161.57990258 138.48217378 184.1382285  171.86395394 162.84756038
#  174.20177712 172.27145762 167.65518435 173.77777706 156.7888126
#  182.97970005 162.49917935 163.75332751 172.78717044 175.55426561
#  162.37973876 189.97390914 175.50566044 175.34441952 168.82305976
#  168.0104671  164.8054295  165.18666228 169.93278769 168.96701068
#  177.8459715  144.6364306  177.5174194  171.62132413 184.92805038
#  181.93673112 181.31314091 150.30370438 170.92701102 157.90944298
#  171.78700985 163.08259976 179.23724256 171.47722917 165.41586044
#  168.05131291 148.09682232 160.42527096 180.75877584 182.69314787
#  165.54175    166.26815575 159.41355302 170.044358   170.45178875
#  176.59931523 168.4839696  167.92754317 179.12901497 175.56412048
#  170.46250095 157.4509998  180.09569922 179.49859547 167.5884445
#  173.70230638 172.68173396 153.43620776 179.70342765 185.27326977
#  184.03841687 169.06395298 166.46287074 200.99162288 166.33924329
#  179.4997937  168.23679814 169.00623815 172.60892181 172.47156823
#  167.50818926 170.66876665 172.3517414  161.56978457 162.60090822
#  172.41738899 168.41054305 177.00122156 161.01374228 161.88616321
#  165.40765042 170.99546038 180.5020479  165.06869959 162.42695432
#  162.8045584  169.05709777 177.41661278 178.89799948 165.59467456
#  173.33827463 153.74684603 175.47098695 171.11574918 187.12542308
#  154.51169376 168.9213755  159.6177655  175.78837201 173.34087763
#  161.47868046 168.44761188 170.24344292 180.5766581  142.6674358
#  180.79130827 166.4011429  163.09341538 184.35284996 173.29155131
#  163.31351269 181.74387039 166.30185449 165.87705438 156.13302157
#  177.40052994 157.87469699 172.96162134 178.61985908 182.06216323
#  164.2987131  158.19310511 169.49652613 172.9578876  171.86020907
#  189.06567197 172.91168067 163.62289406 188.81823108 169.49482586
#  183.30028903 177.85918296 167.57440924 160.17238163 170.74945406
#  173.76441977 179.5054854  167.4751558  149.60641875 157.4462784
#  173.6351573  189.36719828 169.42017691 169.16689182 177.87635796
#  165.04865195 186.41533132 169.66718338 165.55222084 180.33057263
#  166.48494972 178.13477755 169.90251043 186.50121129 181.81525502
#  155.64445723 173.72265679 160.64478854 187.43611618 178.24866359
#  175.78855551 171.86924531 177.626718   163.26809552 181.51175069]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig,ax = plt.subplots()
x=np.linspace(0, 20, 1000)
ax.plot(x, np.cos(x))
ax.axis('equal')
ax.annotate('local maximum', xy=(6.28, 1), xytext=(10,4),
            arrowprops=dict(facecolor='black',shrink=(0.05))
ax.annotate('local minimum',xy=(5*np.pi,-1),xytext=(2,-6),arrowprops=dict(arrowstyle="->",connectionstyle="angle3,angleA=0,angleB=-90"));
# Out:
#   Input In [21]
#     ax.annotate('local minimum',xy=(5*np.pi,-1),xytext=(2,-6),arrowprops=dict(arrowstyle="->",connectionstyle="angle3,angleA=0,angleB=-90"));
#     ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import numpy as np
fig,ax=plt.subplots()
x=np.linspace(0,20,1000)
ax.plot(x,np.cos(x))
ax.axis('equal')
ax.annotate('local maximum',xy=(6.28,1), xytext=(10,4),arrowprops=dict(facecolor='black',shrink=0.05))
ax.annotate('local minimum',xy=(5*np.pi,-1),xytext=(2,-6),arrowprops=dict(arrowstyle="->",connectionstyle="angle3,angleA=0,angleB=-90"));

# %%
w = 4
h = 3
d = 70
plt.figure(figsize=(w,h),dpi=d)
plt.axis([0,5,0,5])
x = [0,3,5]
y = [1,4,3.5]
label_x =1
label_y = 4
arrow_x = 3
arrow_y = 4

arrow_properties = dict(
    facecolor="black", width=0.5,
    headwidth=4, shrink=0.1)

plt.annotate(
   "maximum", xy=(arrow_x, arrow_y),
    xytext=(label_x, label_y),
    arrowprops=arrow_properties)
plt.plot(x,y)

# %%
from mpl_toolkits import mplot3d
import numpy as np

fig = plt.figure()
ax = plt.axes(projection = "3d")
z = np.linspace(0,1,100)
x = z*np.sin(25*z)
y = z * np.cos(25*z)
ax.plot3D(x, y, z, 'green')
ax.set_title("3D line plor")
plt.show()

# %%
cars= ['AUDI' , 'BMW', 'FORD', 'TESLA', 'JAGUAR', 'MERCEDES']
data = [23,17,35,29,12,41]
fig = plt.figure(figsize=(10,7))
plt.pie(data, labels = cars)
plt.show
